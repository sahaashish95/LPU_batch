# %%
import numpy as np
import pandas as pd

market_df = pd.read_csv(r"C:\Users\ashish saha\OneDrive\Desktop\upgrad\pandas\global_sales_data\global_sales_data\market_fact.csv")
market_df.head(10)
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# 5  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.0200      0.03
# 6    Ord_31  Prod_12    SHP_41    Cust_26    14.7600      0.01
# 7  Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 8  Ord_4725  Prod_13  SHP_6593  Cust_1641   162.0000      0.01
# 9  Ord_4725   Prod_6  SHP_6593  Cust_1641    57.2200      0.07
#
#    Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0              23   -30.51           3.60                 0.56
# 1              13     4.56           0.93                 0.54
# 2              26  1148.90           2.50                 0.59
# 3              43   729.34          14.30                 0.37
# 4              35  1219.87          26.30                 0.38
# 5              23   -47.64           6.15                 0.37
# 6               5     1.32           0.50                 0.36
# 7              48  1137.91           0.99                 0.55
# 8              33    45.84           0.71                 0.52
# 9               8   -27.72           6.60                 0.37

# %%
market_df.iloc[4:8,:]
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# 5  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.0200      0.03
# 6    Ord_31  Prod_12    SHP_41    Cust_26    14.7600      0.01
# 7  Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
#
#    Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 4              35  1219.87          26.30                 0.38
# 5              23   -47.64           6.15                 0.37
# 6               5     1.32           0.50                 0.36
# 7              48  1137.91           0.99                 0.55

# %%
market_df.loc[4:8,:]
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# 5  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.0200      0.03
# 6    Ord_31  Prod_12    SHP_41    Cust_26    14.7600      0.01
# 7  Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 8  Ord_4725  Prod_13  SHP_6593  Cust_1641   162.0000      0.01
#
#    Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 4              35  1219.87          26.30                 0.38
# 5              23   -47.64           6.15                 0.37
# 6               5     1.32           0.50                 0.36
# 7              48  1137.91           0.99                 0.55
# 8              33    45.84           0.71                 0.52

# %% [markdown]
# ### Position (Integer) Based Indexing

# %%
market_df.iloc[4, 8]
# Out:
# 26.3

# %%
market_df.iloc[8]
# Out:
# Ord_id                  Ord_4725
# Prod_id                  Prod_13
# Ship_id                 SHP_6593
# Cust_id                Cust_1641
# Sales                      162.0
# Discount                    0.01
# Order_Quantity                33
# Profit                     45.84
# Shipping_Cost               0.71
# Product_Base_Margin         0.52
# Name: 8, dtype: object

# %%
market_df.iloc[9, :]
# Out:
# Ord_id                  Ord_4725
# Prod_id                   Prod_6
# Ship_id                 SHP_6593
# Cust_id                Cust_1641
# Sales                      57.22
# Discount                    0.07
# Order_Quantity                 8
# Profit                    -27.72
# Shipping_Cost                6.6
# Product_Base_Margin         0.37
# Name: 9, dtype: object

# %%
market_df.iloc[[2, 7, 9]]
# Out:
#      Ord_id Prod_id   Ship_id    Cust_id      Sales  Discount  Order_Quantity  \
# 2  Ord_5446  Prod_4  SHP_7610  Cust_1818  4701.6900      0.00              26
# 7  Ord_4725  Prod_4  SHP_6593  Cust_1641  3410.1575      0.10              48
# 9  Ord_4725  Prod_6  SHP_6593  Cust_1641    57.2200      0.07               8
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 2  1148.90           2.50                 0.59
# 7  1137.91           0.99                 0.55
# 9   -27.72           6.60                 0.37

# %%
market_df.iloc[[2, 7, 9], :]
# Out:
#      Ord_id Prod_id   Ship_id    Cust_id      Sales  Discount  Order_Quantity  \
# 2  Ord_5446  Prod_4  SHP_7610  Cust_1818  4701.6900      0.00              26
# 7  Ord_4725  Prod_4  SHP_6593  Cust_1641  3410.1575      0.10              48
# 9  Ord_4725  Prod_6  SHP_6593  Cust_1641    57.2200      0.07               8
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 2  1148.90           2.50                 0.59
# 7  1137.91           0.99                 0.55
# 9   -27.72           6.60                 0.37

# %%
market_df.iloc[3:7]
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
# 5  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# 6    Ord_31  Prod_12    SHP_41    Cust_26    14.76      0.01               5
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38
# 5   -47.64           6.15                 0.37
# 6     1.32           0.50                 0.36

# %%
market_df.iloc[3:7, :]
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
# 5  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# 6    Ord_31  Prod_12    SHP_41    Cust_26    14.76      0.01               5
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38
# 5   -47.64           6.15                 0.37
# 6     1.32           0.50                 0.36

# %%
market_df.iloc[:, 4]
# Out:
# 0        136.8100
# 1         42.2700
# 2       4701.6900
# 3       2337.8900
# 4       4233.1500
#           ...
# 8394    2841.4395
# 8395     127.1600
# 8396     243.0500
# 8397    3872.8700
# 8398     603.6900
# Name: Sales, Length: 8399, dtype: float64

# %%
# Selecting multiple columns
market_df.iloc[:, 3:8]
# Out:
#         Cust_id      Sales  Discount  Order_Quantity   Profit
# 0     Cust_1818   136.8100      0.01              23   -30.51
# 1     Cust_1818    42.2700      0.01              13     4.56
# 2     Cust_1818  4701.6900      0.00              26  1148.90
# 3     Cust_1818  2337.8900      0.09              43   729.34
# 4     Cust_1818  4233.1500      0.08              35  1219.87
# ...         ...        ...       ...             ...      ...
# 8394  Cust_1798  2841.4395      0.08              28   374.63
# 8395  Cust_1798   127.1600      0.10              20   -74.03
# 8396  Cust_1798   243.0500      0.02              39   -70.85
# 8397  Cust_1798  3872.8700      0.03              23   565.34
# 8398  Cust_1798   603.6900      0.00              47   131.39
#
# [8399 rows x 5 columns]

# %%
# Selecting multiple rows and columns
market_df.iloc[3:6, 2:5]
# Out:
#     Ship_id    Cust_id    Sales
# 3  SHP_7625  Cust_1818  2337.89
# 4  SHP_7664  Cust_1818  4233.15
# 5  SHP_7608  Cust_1818   164.02

# %%
# Using booleans
# This selects the rows corresponding to True
market_df.iloc[:,[True, True, False, True, True, False, True,True,True]]
# Out:
#           Prod_id   Ship_id      Sales  Discount   Profit  Shipping_Cost  \
# Ord_id
# Ord_5446  Prod_16  SHP_7609   136.8100      0.01   -30.51           3.60
# Ord_5406  Prod_13  SHP_7549    42.2700      0.01     4.56           0.93
# Ord_5446   Prod_4  SHP_7610  4701.6900      0.00  1148.90           2.50
# Ord_5456   Prod_6  SHP_7625  2337.8900      0.09   729.34          14.30
# Ord_5485  Prod_17  SHP_7664  4233.1500      0.08  1219.87          26.30
# ...           ...       ...        ...       ...      ...            ...
# Ord_5353   Prod_4  SHP_7479  2841.4395      0.08   374.63           7.69
# Ord_5411   Prod_6  SHP_7555   127.1600      0.10   -74.03           6.92
# Ord_5388   Prod_6  SHP_7524   243.0500      0.02   -70.85           5.35
# Ord_5348  Prod_15  SHP_7469  3872.8700      0.03   565.34          30.00
# Ord_5459   Prod_6  SHP_7628   603.6900      0.00   131.39           4.86
#
#           Product_Base_Margin
# Ord_id
# Ord_5446                 0.56
# Ord_5406                 0.54
# Ord_5446                 0.59
# Ord_5456                 0.37
# Ord_5485                 0.38
# ...                       ...
# Ord_5353                 0.59
# Ord_5411                 0.37
# Ord_5388                 0.40
# Ord_5348                 0.62
# Ord_5459                 0.38
#
# [8399 rows x 7 columns]

# %% [markdown]
# To summarise, ```df.iloc[x, y]``` uses integer indices starting at 0.
#
# The other common way of indexing is the **label based** indexing, which uses ```df.loc[]```.

# %% [markdown]
# ### Label Based Indexing

# %%
market_df.loc[4, 'Sales']
# Out:
# 4233.15

# %%
# Selecting a single row using a single label
# df.loc reads 5 as a label, not index
market_df.loc[8]
# Out:
# Ord_id                  Ord_4725
# Prod_id                  Prod_13
# Ship_id                 SHP_6593
# Cust_id                Cust_1641
# Sales                      162.0
# Discount                    0.01
# Order_Quantity                33
# Profit                     45.84
# Shipping_Cost               0.71
# Product_Base_Margin         0.52
# Name: 8, dtype: object

# %%
# or equivalently
market_df.loc[6, :]
# Out:
# Ord_id                  Ord_31
# Prod_id                Prod_12
# Ship_id                 SHP_41
# Cust_id                Cust_26
# Sales                    14.76
# Discount                  0.01
# Order_Quantity               5
# Profit                    1.32
# Shipping_Cost              0.5
# Product_Base_Margin       0.36
# Name: 6, dtype: object

# %%
market_df.loc[[3, 7, 8]]
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 7  Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 8  Ord_4725  Prod_13  SHP_6593  Cust_1641   162.0000      0.01
#
#    Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 3              43   729.34          14.30                 0.37
# 7              48  1137.91           0.99                 0.55
# 8              33    45.84           0.71                 0.52

# %%
market_df.loc[[3, 7, 8], :]
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 7  Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 8  Ord_4725  Prod_13  SHP_6593  Cust_1641   162.0000      0.01
#
#    Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 3              43   729.34          14.30                 0.37
# 7              48  1137.91           0.99                 0.55
# 8              33    45.84           0.71                 0.52

# %%
market_df.loc[4:8]
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# 5  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.0200      0.03
# 6    Ord_31  Prod_12    SHP_41    Cust_26    14.7600      0.01
# 7  Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 8  Ord_4725  Prod_13  SHP_6593  Cust_1641   162.0000      0.01
#
#    Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 4              35  1219.87          26.30                 0.38
# 5              23   -47.64           6.15                 0.37
# 6               5     1.32           0.50                 0.36
# 7              48  1137.91           0.99                 0.55
# 8              33    45.84           0.71                 0.52

# %%
market_df.iloc[6,0]='lpu'

# %%
market_df.loc[4,"ord_id"]
# Out:
# 'lpu'

# %%
market_df.head(10)
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# 5  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.0200      0.03
# 6       lpu  Prod_12    SHP_41    Cust_26    14.7600      0.01
# 7       lpu   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 8  Ord_4725  Prod_13  SHP_6593  Cust_1641   162.0000      0.01
# 9  Ord_4725   Prod_6  SHP_6593  Cust_1641    57.2200      0.07
#
#    Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin ord_id
# 0              23   -30.51           3.60                 0.56    NaN
# 1              13     4.56           0.93                 0.54    NaN
# 2              26  1148.90           2.50                 0.59    NaN
# 3              43   729.34          14.30                 0.37    NaN
# 4              35  1219.87          26.30                 0.38    lpu
# 5              23   -47.64           6.15                 0.37    NaN
# 6               5     1.32           0.50                 0.36    NaN
# 7              48  1137.91           0.99                 0.55    NaN
# 8              33    45.84           0.71                 0.52    NaN
# 9               8   -27.72           6.60                 0.37    NaN

# %%
# Or equivalently
market_df.loc[4:8, ]
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# 5  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.0200      0.03
# 6    Ord_31  Prod_12    SHP_41    Cust_26    14.7600      0.01
# 7  Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 8  Ord_4725  Prod_13  SHP_6593  Cust_1641   162.0000      0.01
#
#    Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 4              35  1219.87          26.30                 0.38
# 5              23   -47.64           6.15                 0.37
# 6               5     1.32           0.50                 0.36
# 7              48  1137.91           0.99                 0.55
# 8              33    45.84           0.71                 0.52

# %%
# Or equivalently
market_df.loc[4:8, :]
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# 5  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.0200      0.03
# 6    Ord_31  Prod_12    SHP_41    Cust_26    14.7600      0.01
# 7  Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 8  Ord_4725  Prod_13  SHP_6593  Cust_1641   162.0000      0.01
#
#    Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 4              35  1219.87          26.30                 0.38
# 5              23   -47.64           6.15                 0.37
# 6               5     1.32           0.50                 0.36
# 7              48  1137.91           0.99                 0.55
# 8              33    45.84           0.71                 0.52

# %%
# The use of label based indexing will be more clear when we have custom row indices
# Let's change the indices to Ord_id
market_df.set_index('Ord_id', inplace = True)
market_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
# Select Ord_id = Ord_5406 and some columns
market_df.loc['Ord_5406', ['Sales', 'Profit', 'Cust_id']]
# Out:
# Sales          42.27
# Profit          4.56
# Cust_id    Cust_1818
# Name: Ord_5406, dtype: object

# %%
# Select multiple orders using labels, and some columns
market_df.loc[['Ord_5406', 'Ord_5446', 'Ord_5485'], 'Sales':'Profit']
# Out:
#             Sales  Discount  Order_Quantity   Profit
# Ord_id
# Ord_5406    42.27      0.01              13     4.56
# Ord_5446   136.81      0.01              23   -30.51
# Ord_5446  4701.69      0.00              26  1148.90
# Ord_5446   164.02      0.03              23   -47.64
# Ord_5485  4233.15      0.08              35  1219.87

# %%
# Using booleans
# This selects the rows corresponding to True
market_df.loc[[True, True, False, True, True, False, True]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-3a51f024493e> in <module>
#       1 # Using booleans
#       2 # This selects the rows corresponding to True
# ----> 3 market_df.loc[[True, True, False, True, True, False, True]]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1102             return self._get_slice_axis(key, axis=axis)
#    1103         elif com.is_bool_indexer(key):
# -> 1104             return self._getbool_axis(key, axis=axis)
#    1105         elif is_list_like_indexer(key):
#    1106
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getbool_axis(self, key, axis)
#     910         # caller is responsible for ensuring non-None axis
#     911         labels = self.obj._get_axis(axis)
# --> 912         key = check_bool_indexer(labels, key)
#     913         inds = key.nonzero()[0]
#     914         return self.obj._take_with_is_copy(inds, axis=axis)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in check_bool_indexer(index, key)
#    2280         # key may contain nan elements, check_array_indexer needs bool array
#    2281         result = pd_array(result, dtype=bool)
# -> 2282     return check_array_indexer(index, result)
#    2283
#    2284
#
# ~\anaconda3\lib\site-packages\pandas\core\indexers.py in check_array_indexer(array, indexer)
#     483         # GH26658
#     484         if len(indexer) != len(array):
# --> 485             raise IndexError(
#     486                 f"Boolean index has wrong length: "
#     487                 f"{len(indexer)} instead of {len(array)}"
#
# IndexError: Boolean index has wrong length: 7 instead of 8399

# %% [markdown]
# Often, you want to select rows which satisfy some given conditions. For e.g., select all the orders where the ```Sales > 3000```, or all the orders where ```2000 < Sales < 3000``` and ```Profit < 100```.

# %%
## Answer
